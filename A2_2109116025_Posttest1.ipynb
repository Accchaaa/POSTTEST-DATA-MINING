# %% [markdown]
# <a href="https://colab.research.google.com/github/Accchaaa/POSTTEST-DATA-MINING/blob/main/A2_2109116025_Posttest1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# <h1>Posttest Praktikum Data Mining Sistem Informasi </h1>
#
# 2109116025
#
# Sintia Amanda

# %% [markdown]
# ##Business Undestanding & Data Understanding

# %%
import pandas as pd
import seaborn as sns
import plotly.express as px

# %%
df = pd.read_csv("ChurnBank.csv")

# %%
df
# Out:
#     Unnamed: 0  CLIENTNUM     Attrition_Flag  Customer_Age Gender  \
# 0         6036  720010608  Attrited Customer            37      M
# 1         6684  711323283  Attrited Customer            57      M
# 2         4272  794707083  Attrited Customer            50      M
# 3         9759  709657533  Attrited Customer            44      M
# 4         4740  716625033  Attrited Customer            32      F
# 5         9597  715076358  Attrited Customer            57      M
# 6         5009  804829533  Attrited Customer            59      M
# 7         8200  712144158  Attrited Customer            53      F
# 8         5016  795599883  Attrited Customer            57      F
# 9         8350  709222008  Attrited Customer            41      M
# 10        8139  809844108  Existing Customer            48      M
# 11         176  716264358  Existing Customer            53      M
# 12        8020  778163508  Existing Customer            37      F
# ...

# %% [markdown]
# ### Business Understanding

# %% [markdown]
# Perusahaan ini bergerak dibidang operator seluler, yang sudah banyak diminati oleh masyarakat. Namun, seiring berjalannya waktu yang menjadi permasalahan dalam perusahaan adalah ketika adanya customer yang berhenti menggunakan langganan (churn customer) dan beralih ke operator lain.
# Tujuan perusahaan saat ini akan fokus dalam mempertahankan customer, perusahaan telekomunikasi membutuhkan cara untuk memprediksi dan mengetahui risiko kapan customer akan menjadi churn.
# Dataset yang ada akan digunakan untuk melakukan prediksi terhadap customer churn dengan menggunakan algoritma naive  bayes.

# %% [markdown]
# ### Data Understanding

# %%
# dataset dengan label target AttiredCustomer
df1 = df[df["Attrition_Flag"] == "Attrited Customer"]

# %%
df1
# Out:
#    Unnamed: 0  CLIENTNUM     Attrition_Flag  Customer_Age Gender  \
# 0        6036  720010608  Attrited Customer            37      M
# 1        6684  711323283  Attrited Customer            57      M
# 2        4272  794707083  Attrited Customer            50      M
# 3        9759  709657533  Attrited Customer            44      M
# 4        4740  716625033  Attrited Customer            32      F
# 5        9597  715076358  Attrited Customer            57      M
# 6        5009  804829533  Attrited Customer            59      M
# 7        8200  712144158  Attrited Customer            53      F
# 8        5016  795599883  Attrited Customer            57      F
# 9        8350  709222008  Attrited Customer            41      M
#
#   Education_Level Marital_Status Income_Category Card_Category  Credit_Limit
# 0         Unknown         Single     $40K - $60K          Blue       10226.0
# 1      Uneducated        Married     $60K - $80K          Blue        2527.0
# ...

# %%
# dataset dengan label bukan Attrired customer
df2 = df[df["Attrition_Flag"] != "Attrited Customer"]

# %%
df2
# Out:
#     Unnamed: 0  CLIENTNUM     Attrition_Flag  Customer_Age Gender  \
# 10        8139  809844108  Existing Customer            48      M
# 11         176  716264358  Existing Customer            53      M
# 12        8020  778163508  Existing Customer            37      F
# 13         357  711857733  Existing Customer            49      M
# 14        6562  720070383  Existing Customer            41      F
# 15        4563  809809008  Existing Customer            47      F
# 16       10084  718161708  Existing Customer            46      F
# 17        5725  771079833  Existing Customer            40      F
# 18        2587  711639708  Existing Customer            42      M
# 19        8226  713700258  Existing Customer            55      F
#
#    Education_Level Marital_Status Income_Category Card_Category  Credit_Limit
# 10       Doctorate         Single     $60K - $80K          Blue        8086.0
# 11      Uneducated        Married    $80K - $120K          Blue       26792.0
# ...

# %%
# dataset dengan tabel untuk usia dibawah 50 tahun
df3 = df[df["Customer_Age"] < 50]

# %%
df3
# Out:
#     Unnamed: 0  CLIENTNUM     Attrition_Flag  Customer_Age Gender  \
# 0         6036  720010608  Attrited Customer            37      M
# 3         9759  709657533  Attrited Customer            44      M
# 4         4740  716625033  Attrited Customer            32      F
# 9         8350  709222008  Attrited Customer            41      M
# 10        8139  809844108  Existing Customer            48      M
# 12        8020  778163508  Existing Customer            37      F
# 13         357  711857733  Existing Customer            49      M
# 14        6562  720070383  Existing Customer            41      F
# 15        4563  809809008  Existing Customer            47      F
# 16       10084  718161708  Existing Customer            46      F
# 17        5725  771079833  Existing Customer            40      F
# 18        2587  711639708  Existing Customer            42      M
#
#    Education_Level Marital_Status Income_Category Card_Category  Credit_Limit
# ...

# %%
# dataset dengan customer yang statusnya itu single
df4 = df[df["Marital_Status"] == "Single"]

# %%
df4
# Out:
#     Unnamed: 0  CLIENTNUM     Attrition_Flag  Customer_Age Gender  \
# 0         6036  720010608  Attrited Customer            37      M
# 2         4272  794707083  Attrited Customer            50      M
# 4         4740  716625033  Attrited Customer            32      F
# 6         5009  804829533  Attrited Customer            59      M
# 7         8200  712144158  Attrited Customer            53      F
# 9         8350  709222008  Attrited Customer            41      M
# 10        8139  809844108  Existing Customer            48      M
# 13         357  711857733  Existing Customer            49      M
# 14        6562  720070383  Existing Customer            41      F
# 17        5725  771079833  Existing Customer            40      F
# 18        2587  711639708  Existing Customer            42      M
#
#    Education_Level Marital_Status Income_Category Card_Category  Credit_Limit
# 0          Unknown         Single     $40K - $60K          Blue       10226.0
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20 entries, 0 to 19
# Data columns (total 10 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Unnamed: 0       20 non-null     int64
#  1   CLIENTNUM        20 non-null     int64
#  2   Attrition_Flag   20 non-null     object
#  3   Customer_Age     20 non-null     int64
#  4   Gender           20 non-null     object
#  5   Education_Level  20 non-null     object
#  6   Marital_Status   20 non-null     object
#  7   Income_Category  20 non-null     object
#  8   Card_Category    20 non-null     object
#  9   Credit_Limit     20 non-null     float64
# dtypes: float64(1), int64(3), object(6)
# memory usage: 1.7+ KB

# %% [markdown]
#  #### Opsional (Nilai Plus)

# %%
#nilai rata-rata, min,max, dan standar deviasi  untuk kolom bertipe angka
dfa = df.aggregate({"Unnamed: 0":["min", "max", "mean", "std"],
                    "CLIENTNUM":["min", "max", "mean", "std"],
                     "Customer_Age":["min", "max", "mean", "std"],
                     "Credit_Limit":["min", "max", "mean", "std"]})

# %%
dfa
# Out:
#         Unnamed: 0     CLIENTNUM  Customer_Age  Credit_Limit
# min     176.000000  7.092220e+08     32.000000   1438.300000
# max   10084.000000  8.098441e+08     59.000000  26792.000000
# mean   6105.100000  7.424893e+08     47.250000   8114.580000
# std    2850.304026  4.045524e+07      7.859791   8331.036819

# %% [markdown]
# ### Explore Data

# %% [markdown]
# ##### Visualisasi Comparison

# %%
# Visualisasi1 yang menampilkan berapa banyak yang attired customer dan tidak
sns.countplot(data=df, x="Attrition_Flag")
# Out:
# <AxesSubplot:xlabel='Attrition_Flag', ylabel='count'>

# %%
# Visualisasi2 yang menampilkan berapa banyak Education level berdasarkan kategori-kategorinya 
sns.countplot(data=df, x="Education_Level")
# Out:
# <AxesSubplot:xlabel='Education_Level', ylabel='count'>

# %%
# Visualisasi3 yang menampilkan berapa banyak Education level berdasarkan gendernya
sns.countplot(data=df, x="Gender", hue = "Education_Level")
# Out:
# <AxesSubplot:xlabel='Gender', ylabel='count'>

# %% [markdown]
# ### Penjelasan Visualisasi
#
# Visualisasi1
#
# Pada visualisasi 1 ini nilai attrited customer dan exciting customer sebanding atau memiliki nilai yang setara
#
#
# Visualisasi2
#
# Pada visualisasi2 ini terdapat 7 kategori education level yang memiliki nilai berbeda, dengan kategori uneducation dan graduate memiliki nilai paling tinggi.
#
# Visualisasi3
#
# Visualisasi3 ini menampilkan berapa banyak Education level berdasarkan gendernya

# %% [markdown]
# ##### Visualisasi Distribution

# %%
# Histogram untuk customer dan credit card limit
sns.histplot(data=df,x="Credit_Limit")
# Out:
# <AxesSubplot:xlabel='Credit_Limit', ylabel='Count'>

# %%
sns.histplot(data=df,x="Customer_Age")
# Out:
# <AxesSubplot:xlabel='Customer_Age', ylabel='Count'>

# %%
# Boxplot untuk customer dan credit card limit
sns.boxplot(data=df,x="Credit_Limit")
# Out:
# <AxesSubplot:xlabel='Credit_Limit'>

# %%
sns.boxplot(data=df,x="Customer_Age")
# Out:
# <AxesSubplot:xlabel='Customer_Age'>

# %% [markdown]
# berikan penjelasannya disini

# %% [markdown]
# #### Visualisasi Relationship

# %%
# Scatterplot untuk umur customer dan credit card limit
sns.scatterplot(data=df,x="Customer_Age",y="Credit_Limit")
# Out:
# <AxesSubplot:xlabel='Customer_Age', ylabel='Credit_Limit'>

# %% [markdown]
# #### Visualisasi Composition

# %%
# pieplot untuk Income Category & Education Level
px.pie(df,names="Education_Level")
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
px.pie(df,names="Income_Category")
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# ### Optional

# %%
# visualisasi boxplot Credit Card Limit dengan Jenis Kelamin sebagai pemisahnya (color)
sns.boxplot(data=df, x="Credit_Limit", y="Gender")

# %%
# visualisasi boxplot Credit Card Limit dengan Attrition Flag sebagai pemisahnya (color)
sns.boxplot(data=df, x = "Credit_Limit", y="Attrition_Flag")

# %%
# visualisasi boxplot Age dengan Attrition Flag sebagai pemisahnya (color)
sns.boxplot(data=df, x = "Customer_Age", y="Attrition_Flag")

# %%
# visualisasi countplot  Attrition Flag dengan jenis kelamin sebagai pemisahnya (color)
sns.countplot(data=df, x = "Attrition_Flag", y="Gender")

# %%
# visualisasi countplot  Attrition Flag dengan jenis kelamin sebagai pemisahnya (color)
sns.countplot(data=df, x="Attrition_Flag", hue="Gender")

# %%
# visualisasi heatmap untuk Setiap variabel numerik yang ada
dfb = df[['Unnamed: 0', 'CLIENTNUM', 'Customer_Age', 'Credit_Limit']]
sns.heatmap(data=dfb)
dfb

# %%
# sebelum membuat algoritma pertama tama buatlah dataset baru dengan ketentuan
# mengambil dataset df
# Menghapus kolom Unnamed: 0, CLIENTNUM, Umur, dan Limit Kartu Kredit (initinya yang berupa primary key dan bukan tipe kategori)
# dataset dengan kolom yang sudah dihapus tadi kemudian disimpan di dataframe baru (df baru)

# %%
dfc = df.drop(['Unnamed: 0', 'CLIENTNUM', 'Customer_Age', 'Credit_Limit'], axis=1)
dfc
# Out:
#        Attrition_Flag Gender Education_Level Marital_Status Income_Category  \
# 0   Attrited Customer      M         Unknown         Single     $40K - $60K
# 1   Attrited Customer      M      Uneducated        Married     $60K - $80K
# 2   Attrited Customer      M         College         Single    $80K - $120K
# 3   Attrited Customer      M     High School        Unknown         $120K +
# 4   Attrited Customer      F        Graduate         Single  Less than $40K
# 5   Attrited Customer      M   Post-Graduate        Unknown    $80K - $120K
# 6   Attrited Customer      M     High School         Single     $60K - $80K
# 7   Attrited Customer      F        Graduate         Single  Less than $40K
# 8   Attrited Customer      F      Uneducated        Married         Unknown
# 9   Attrited Customer      M         Unknown         Single    $80K - $120K
# 10  Existing Customer      M       Doctorate         Single     $60K - $80K
# ...

# %%
# Buatlah sebuah fungsi naive bayes dengan ketentuan
# Mengambil data dari dataframe yang telah diproses pada blok sebelumnya (diatas)
# Nama fungsinya adalah naive_bayes
# Mengambil 1 saja parameter yaitu sebuah list berisi kategori

# Outputnya berupa prediksi Attrited Customer atau Existing Customer
# Outputnya berupa tuple (_hasilnya, persentasenya berapa) contoh (Existing Customer, 0.004)

# Tidak boleh menggunakan library manapun selain pandas dan numpy

# contoh
# def naive_bayes(prediksi:list)-> tuple :
#   ........

# jadi nanti saat saya coba masukan data 
# naive_bayes(["F",	"Uneducated","Single", "Unknown	Blue"]) akan keluar tuple berupa ("Attired Customer", 0.002)

# %%
def naivebayes(prediksi:list):
  a = dfc[dfc.Attrition_Flag == 'Attrited Customer'] #dataset khusus Attrited Customer
  case_a = len(a)/len(dfc) #peluang kasus Attrited Customer

  b = dfc[dfc.Attrition_Flag == 'Existing Customer'] #dataset khusus Existing Customer
  case_b = len(b)/len(dfc) #peluang kasus Existing Customer

  #Hitung nilai P(XK|Ci) untuk setiap kelas i
  for i in range(len(prediksi)):
    p_a = a[a.iloc[:,i] == prediksi[i]]
    #Variabel kemungkinan Attrited Customer dengan mengambil index location/iloc dari index kolom dataset AC
    p_b = b[b.iloc[:,i] == prediksi[i]]
    #Variabel kemungkinan Attrited Customer dengan mengambil index location/iloc dari index kolom dataset EX

    #Jumlah total setiap kasus (termasuk setiap data unik pada keseluruhan dataset/dfn)
    c = len(a) + len(dfc.iloc[:,i].unique())
    d = len(b) + len(dfc.iloc[:,i].unique())

    peluang_baru_a = (len(p_a) +1) / c
    peluang_baru_b = (len(p_b) +1) / d

  #Hitung nilai P(X|Ci) untuk setiap Kelas (Label)
    if i == 0: #jika nilainya nol, maka akan tetap nol.
      peluang_terjadi_a = peluang_baru_a
      peluang_terjadi_b = peluang_baru_b
    else: #jika tidak, maka dapat dikalikan 
      peluang_terjadi_a *= peluang_baru_a
      peluang_terjadi_b *= peluang_baru_b

  #Hitung nilai P(X|Ci) * P(Ci)
  peluang_baru_a = case_a * peluang_terjadi_a
  peluang_baru_b = case_b * peluang_terjadi_b

  #Menetukan klas dari kasus
  total_p = peluang_baru_a + peluang_baru_b
  perbandingan = peluang_baru_b / total_p
  output = 'Attrited Customer' if perbandingan < 0.5 else 'Existing Customer'
  turn = str(perbandingan)
  print('Hasil perhitungan akhir adalah ' + output + ' dengan nilai peluang ' + turn)

naivebayes(["F", "Uneducated", "Single", "Unknown", "Blue"])
naivebayes(["M", "Graduate", "Single", "Less than $40K", "Blue"])
